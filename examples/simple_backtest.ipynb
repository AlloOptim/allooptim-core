# %% [markdown]
# # Simple Backtest Example
#
# This notebook demonstrates a fast backtest of portfolio optimization algorithms during a volatile period where A2A ensemble methods can shine.

# %% [markdown]
# ## 1. Import Libraries
#
# Import the necessary libraries for backtesting.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# AlloOptim imports
from allooptim.backtest.backtest_config import BacktestConfig
from allooptim.backtest.backtest_engine import BacktestEngine

print("Libraries imported successfully!")
# Out:
# INFO:allooptim:AlloOptim package initialized successfully
# Libraries imported successfully!

# %% [markdown]
# ## 2. Configure Backtest
#
# Set up a fast backtest for a volatile period (COVID crash) where A2A ensemble methods excel.

# %%
# Configure a fast backtest for volatile period (COVID crash)
config = BacktestConfig(
    # Required fields
    start_date=datetime(2020, 3, 1),
    end_date=datetime(2020, 6, 30),
    # Short volatile period where A2A shines (March-June 2020)
    quick_start_date=datetime(2020, 3, 1),
    quick_end_date=datetime(2020, 6, 30),
    # Fast settings for quick execution
    rebalance_frequency=5,  # Rebalance every 5 trading days
    lookback_days=30,  # Use 30 days of historical data
    # Simple asset universe
    symbols=["AAPL", "MSFT", "AMZN", "GOOGL", "TSLA", "SPY"],
    # Use A2A with a few diverse optimizers
    optimizer_names=["MaxSharpe", "RiskParityOptimizer", "NaiveOptimizer", "MomentumOptimizer", "HRPOptimizer", "NCOSharpeOptimizer"],
    # Quick test mode
    quick_test=True,
    # Do not store results to disk for notebook environment
    store_results=False,
)

# %% [markdown]
# ## 3. Run Backtest
#
# Execute the fast backtest to see how individual optimizers and A2A ensemble perform during market volatility.

# %%
# Initialize and run the backtest
print("Initializing backtest engine...")
backtest_engine = BacktestEngine(config)

print("Running fast backtest...")
print("This should complete in under 30 seconds...")

# Run the backtest
results = backtest_engine.run_backtest()

if results:
    print("✅ Backtest completed successfully!")
    print(f"   Tested {len([k for k in results.keys() if k != 'SPY_Benchmark'])} optimizers + A2A + benchmark")
else:
    print("❌ Backtest failed")
    raise RuntimeError("Backtest execution failed")
# Out:
# 2025-11-06 06:19:07,309 - allooptim.backtest.data_loader - INFO - Loaded universe with 6 symbols
# 2025-11-06 06:19:07,313 - allooptim.backtest.backtest_engine - INFO - Starting comprehensive backtest
# 2025-11-06 06:19:07,313 - allooptim.backtest.backtest_engine - INFO - Starting comprehensive backtest
# 2025-11-06 06:19:07,313 - allooptim.backtest.data_loader - INFO - Loading price data from 2020-01-31 00:00:00 to 2020-06-30 00:00:00
# 2025-11-06 06:19:07,320 - allooptim.backtest.data_loader - INFO - Loading batch 1: 6 symbols
# 2025-11-06 06:19:07,313 - allooptim.backtest.data_loader - INFO - Loading price data from 2020-01-31 00:00:00 to 2020-06-30 00:00:00
# 2025-11-06 06:19:07,320 - allooptim.backtest.data_loader - INFO - Loading batch 1: 6 symbols
# Initializing backtest engine...
# Running fast backtest...
# This should complete in under 30 seconds...
# 2025-11-06 06:19:09,223 - allooptim.backtest.data_cleaning - INFO - Raw price data shape: (104, 6)
# 2025-11-06 06:19:09,229 - allooptim.backtest.data_cleaning - WARNING - Very few symbols remain after cleaning: 6 (required: 10)
# 2025-11-06 06:19:09,233 - allooptim.backtest.data_cleaning - INFO - Clean price data shape: (104, 6) (dropped 0 symbols)
# 2025-11-06 06:19:09,229 - allooptim.backtest.data_cleaning - WARNING - Very few symbols remain after cleaning: 6 (required: 10)
# 2025-11-06 06:19:09,233 - allooptim.backtest.data_cleaning - INFO - Clean price data shape: (104, 6) (dropped 0 symbols)
# 2025-11-06 06:19:09,235 - allooptim.backtest.data_loader - INFO - Loaded data for 6 assets over 104 days
# 2025-11-06 06:19:09,240 - allooptim.backtest.backtest_engine - INFO - Running backtest with 15 rebalancing dates
# 2025-11-06 06:19:09,240 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 1/15: 2020-03-16 00:00:00
# 2025-11-06 06:19:09,235 - allooptim.backtest.data_loader - INFO - Loaded data for 6 assets over 104 days
# 2025-11-06 06:19:09,240 - allooptim.backtest.backtest_engine - INFO - Running backtest with 15 rebalancing dates
# 2025-11-06 06:19:09,240 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 1/15: 2020-03-16 00:00:00
# 2025-11-06 06:19:09,262 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:09,262 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:09,294 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:09,294 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:12,892 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:12,893 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:12,900 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:12,892 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:12,893 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:12,900 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:12,909 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:12,915 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 2/15: 2020-03-23 00:00:00
# 2025-11-06 06:19:12,909 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:12,915 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 2/15: 2020-03-23 00:00:00
# 2025-11-06 06:19:12,930 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:12,930 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:12,970 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:12,987 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:12,970 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:12,987 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:12,991 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:12,995 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,006 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:12,991 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:12,995 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,006 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,011 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 3/15: 2020-03-30 00:00:00
# 2025-11-06 06:19:13,011 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 3/15: 2020-03-30 00:00:00
# 2025-11-06 06:19:13,028 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,028 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,061 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,069 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,069 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,061 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,069 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,069 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,074 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,084 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,074 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,084 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,109 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 4/15: 2020-04-06 00:00:00
# 2025-11-06 06:19:13,109 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 4/15: 2020-04-06 00:00:00
# 2025-11-06 06:19:13,128 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,128 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,157 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,162 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,169 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,157 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,162 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,169 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,171 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,180 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,171 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,180 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,202 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 5/15: 2020-04-14 00:00:00
# 2025-11-06 06:19:13,219 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,202 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 5/15: 2020-04-14 00:00:00
# 2025-11-06 06:19:13,219 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,243 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,264 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,243 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,264 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,269 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,274 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,278 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,269 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,274 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,278 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,308 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 6/15: 2020-04-21 00:00:00
# 2025-11-06 06:19:13,308 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 6/15: 2020-04-21 00:00:00
# 2025-11-06 06:19:13,331 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,331 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,461 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,461 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,504 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,507 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,513 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,504 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,507 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,513 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,520 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,520 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,536 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 7/15: 2020-04-28 00:00:00
# 2025-11-06 06:19:13,536 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 7/15: 2020-04-28 00:00:00
# 2025-11-06 06:19:13,568 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,568 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,607 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,607 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,617 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,623 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,628 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,617 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,623 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,628 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,639 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,639 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,658 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 8/15: 2020-05-05 00:00:00
# 2025-11-06 06:19:13,658 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 8/15: 2020-05-05 00:00:00
# 2025-11-06 06:19:13,675 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,675 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,706 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,720 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,706 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,720 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,724 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,730 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,737 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,724 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,730 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,737 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,759 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 9/15: 2020-05-12 00:00:00
# 2025-11-06 06:19:13,759 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 9/15: 2020-05-12 00:00:00
# 2025-11-06 06:19:13,777 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,777 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,808 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,830 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,808 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,830 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,832 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,838 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,843 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,832 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,838 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,843 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,862 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 10/15: 2020-05-19 00:00:00
# 2025-11-06 06:19:13,862 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 10/15: 2020-05-19 00:00:00
# 2025-11-06 06:19:13,891 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,891 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,921 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,935 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,921 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:13,935 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:13,941 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,947 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,941 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:13,947 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:13,957 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,957 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:13,980 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 11/15: 2020-05-27 00:00:00
# 2025-11-06 06:19:13,980 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 11/15: 2020-05-27 00:00:00
# 2025-11-06 06:19:13,996 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:13,996 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,024 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,036 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,039 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,024 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,036 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,039 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,042 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,052 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,042 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,052 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,075 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 12/15: 2020-06-03 00:00:00
# 2025-11-06 06:19:14,075 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 12/15: 2020-06-03 00:00:00
# 2025-11-06 06:19:14,088 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,088 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,128 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,138 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,128 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,138 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,141 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,146 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,141 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,146 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,156 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,156 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,184 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 13/15: 2020-06-10 00:00:00
# 2025-11-06 06:19:14,184 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 13/15: 2020-06-10 00:00:00
# 2025-11-06 06:19:14,200 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,200 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,230 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,230 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,245 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,248 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,257 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,245 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,248 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,257 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,268 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,268 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,298 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 14/15: 2020-06-17 00:00:00
# 2025-11-06 06:19:14,298 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 14/15: 2020-06-17 00:00:00
# 2025-11-06 06:19:14,321 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,321 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,355 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,365 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,355 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,365 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,369 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,377 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,382 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,369 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,377 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,382 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,411 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 15/15: 2020-06-24 00:00:00
# 2025-11-06 06:19:14,431 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,411 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 15/15: 2020-06-24 00:00:00
# 2025-11-06 06:19:14,431 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-06 06:19:14,470 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,476 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,470 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-06 06:19:14,476 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-06 06:19:14,480 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,488 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,488 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,480 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-06 06:19:14,488 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-06 06:19:14,488 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-06 06:19:14,519 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MaxSharpe
# 2025-11-06 06:19:14,519 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MaxSharpe
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4671: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# 2025-11-06 06:19:14,771 - allooptim.backtest.backtest_engine - INFO - Calculating performance for RiskParityOptimizer
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4671: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# 2025-11-06 06:19:14,771 - allooptim.backtest.backtest_engine - INFO - Calculating performance for RiskParityOptimizer
# 2025-11-06 06:19:14,964 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NaiveOptimizer
# 2025-11-06 06:19:14,964 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NaiveOptimizer
# 2025-11-06 06:19:15,152 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MomentumOptimizer
# 2025-11-06 06:19:15,152 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MomentumOptimizer
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4673: RuntimeWarning: invalid value encountered in multiply
#   lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
# 2025-11-06 06:19:15,355 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NCOSharpeOptimizer
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4673: RuntimeWarning: invalid value encountered in multiply
#   lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
# 2025-11-06 06:19:15,355 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NCOSharpeOptimizer
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4674: RuntimeWarning: invalid value encountered in subtract
#   subtract(b, diff_b_a * (1 - t), out=lerp_interpolation, where=t >= 0.5,
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4671: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4674: RuntimeWarning: invalid value encountered in subtract
#   subtract(b, diff_b_a * (1 - t), out=lerp_interpolation, where=t >= 0.5,
# c:\Users\jonas\Git\allooptim-core\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:4671: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# 2025-11-06 06:19:15,586 - allooptim.backtest.backtest_engine - INFO - Calculating performance for HRPOptimizer
# 2025-11-06 06:19:15,586 - allooptim.backtest.backtest_engine - INFO - Calculating performance for HRPOptimizer
# 2025-11-06 06:19:15,807 - allooptim.backtest.backtest_engine - INFO - Calculating performance for SPY benchmark
# 2025-11-06 06:19:15,807 - allooptim.backtest.backtest_engine - INFO - Calculating performance for SPY benchmark
# 2025-11-06 06:19:15,964 - allooptim.backtest.backtest_engine - INFO - Calculating A2A ensemble performance
# 2025-11-06 06:19:15,964 - allooptim.backtest.backtest_engine - INFO - Calculating A2A ensemble performance
# 2025-11-06 06:19:16,173 - allooptim.backtest.backtest_engine - INFO - Results directory not created, skipping A2A allocation save
# 2025-11-06 06:19:16,177 - allooptim.backtest.backtest_engine - INFO - Backtest completed
# 2025-11-06 06:19:16,173 - allooptim.backtest.backtest_engine - INFO - Results directory not created, skipping A2A allocation save
# 2025-11-06 06:19:16,177 - allooptim.backtest.backtest_engine - INFO - Backtest completed
# ✅ Backtest completed successfully!
#    Tested 8 optimizers + A2A + benchmark

# %% [markdown]
# ## 4. Analyze Results
#
# Compare the performance of individual optimizers vs A2A ensemble during the volatile COVID period.

# %%
# Extract performance data for analysis
performance_data = []

for name, data in results.items():
    if 'metrics' in data and 'sharpe_ratio' in data['metrics']:
        row = {'strategy': name}
        row.update(data['metrics'])
        performance_data.append(row)

# Create DataFrame for analysis
df_results = pd.DataFrame(performance_data)
df_results = df_results.sort_values('sharpe_ratio', ascending=False)

print("Backtest Results Summary (COVID Crash Period):")
print("=" * 60)
print(f"Test period: March-June 2020 (High volatility)")
print(f"Strategies tested: {len(df_results)}")
print(f"Available strategies: {', '.join(df_results['strategy'].tolist())}")
print()

# Show top performers
print("Performance Rankings:")
print("-" * 40)
for i, row in df_results.head().iterrows():
    print(f"{i+1:2d}. {row['strategy']}: Sharpe = {row['sharpe_ratio']:.3f}")

print()

# Check if A2A outperformed individual optimizers
a2a_sharpe = df_results[df_results['strategy'] == 'A2AEnsemble']['sharpe_ratio'].iloc[0]
individual_avg = df_results[df_results['strategy'] != 'A2AEnsemble']['sharpe_ratio'].mean()

print("A2A Ensemble Analysis:")
print("-" * 40)
print(f"A2A Sharpe Ratio: {a2a_sharpe:.3f}")
print(f"Average Individual Sharpe: {individual_avg:.3f}")

# Check for benchmark if available
benchmark_strategies = [s for s in df_results['strategy'] if 'benchmark' in s.lower() or 'spy' in s.lower()]
if benchmark_strategies:
    spy_sharpe = df_results[df_results['strategy'] == benchmark_strategies[0]]['sharpe_ratio'].iloc[0]
    print(f"Benchmark ({benchmark_strategies[0]}) Sharpe: {spy_sharpe:.3f}")
    print(f"A2A vs Benchmark: {a2a_sharpe - spy_sharpe:.3f}")
else:
    print("No benchmark strategy found in results")

print(f"A2A vs Individual: {a2a_sharpe - individual_avg:.3f}")
print()
# Out:
# Backtest Results Summary (COVID Crash Period):
# ============================================================
# Test period: March-June 2020 (High volatility)
# Strategies tested: 8
# Available strategies: MaxSharpe, MomentumOptimizer, HRPOptimizer, RiskParityOptimizer, NaiveOptimizer, A2AEnsemble, NCOSharpeOptimizer, SPYBenchmark
#
# Performance Rankings:
# ----------------------------------------
#  1. MaxSharpe: Sharpe = 3.240
#  4. MomentumOptimizer: Sharpe = 3.101
#  6. HRPOptimizer: Sharpe = 2.101
#  2. RiskParityOptimizer: Sharpe = 2.092
#  3. NaiveOptimizer: Sharpe = 2.092
#
# A2A Ensemble Analysis:
# ----------------------------------------
# A2A Sharpe Ratio: 2.043
# Average Individual Sharpe: 2.187
# Benchmark (SPYBenchmark) Sharpe: 0.995
# A2A vs Benchmark: 1.048
# A2A vs Individual: -0.144

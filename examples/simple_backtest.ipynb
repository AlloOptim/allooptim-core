# %% [markdown]
# # Simple Backtest Example
#
# This notebook demonstrates a fast backtest of portfolio optimization algorithms during a volatile period where A2A ensemble methods can shine.

# %% [markdown]
# ## 1. Import Libraries
#
# Import the necessary libraries for backtesting.

# %%
import pandas as pd
from datetime import datetime

from allooptim.config.backtest_config import BacktestConfig
from allooptim.backtest.backtest_engine import BacktestEngine

print("Libraries imported successfully!")
# Out:
# INFO:allooptim:AlloOptim package initialized successfully
# Libraries imported successfully!

# %% [markdown]
# ## 2. Configure Backtest
#
# Set up a fast backtest for a volatile period (COVID crash) where A2A ensemble methods excel.

# %%
# Configure a fast backtest for volatile period (COVID crash)
config_backtest = BacktestConfig(
    # Required fields
    start_date=datetime(2020, 3, 1),
    end_date=datetime(2020, 6, 30),
    # Short volatile period where A2A shines (March-June 2020)
    quick_start_date=datetime(2020, 3, 1),
    quick_end_date=datetime(2020, 6, 30),
    # Fast settings for quick execution
    rebalance_frequency=5,  # Rebalance every 5 trading days
    lookback_days=30,  # Use 30 days of historical data
    # Simple asset universe
    symbols=["AAPL", "MSFT", "AMZN", "GOOGL", "TSLA", "SPY"],
    # Use A2A with a few diverse optimizers
    optimizer_configs=[
        "MaxSharpe",
        "RiskParityOptimizer",
        "NaiveOptimizer",
        "MomentumOptimizer",
        "HRPOptimizer",
        "NCOSharpeOptimizer",
    ],
    # Quick test mode
    quick_test=True,
    # Do not store results to disk for notebook environment
    store_results=False,
)

# %% [markdown]
# ## 3. Run Backtest
#
# Execute the fast backtest to see how individual optimizers and A2A ensemble perform during market volatility.

# %%
# Initialize and run the backtest
print("Initializing backtest engine...")
backtest_engine = BacktestEngine(config_backtest)

print("Running fast backtest...")
print("This should complete in under 30 seconds...")

# Run the backtest
results = backtest_engine.run_backtest()

if results:
    print("✅ Backtest completed successfully!")
    print(f"   Tested {len([k for k in results.keys() if k != 'SPY_Benchmark'])} optimizers + A2A + benchmark")
else:
    print("❌ Backtest failed")
    raise RuntimeError("Backtest execution failed")
# Out:
# 2025-11-19 12:22:08,996 - allooptim.backtest.data_loader - INFO - Loaded universe with 6 symbols
# 2025-11-19 12:22:09,005 - allooptim.backtest.backtest_engine - INFO - Starting comprehensive backtest
# 2025-11-19 12:22:09,005 - allooptim.backtest.data_loader - INFO - Loading price data from 2020-01-31 00:00:00 to 2020-06-30 00:00:00
# 2025-11-19 12:22:09,005 - allooptim.backtest.backtest_engine - INFO - Starting comprehensive backtest
# 2025-11-19 12:22:09,005 - allooptim.backtest.data_loader - INFO - Loading price data from 2020-01-31 00:00:00 to 2020-06-30 00:00:00
# 2025-11-19 12:22:09,010 - allooptim.backtest.data_loader - INFO - Loading batch 1: 6 symbols
# 2025-11-19 12:22:09,010 - allooptim.backtest.data_loader - INFO - Loading batch 1: 6 symbols
# Initializing backtest engine...
# Running fast backtest...
# This should complete in under 30 seconds...
# 2025-11-19 12:22:09,916 - allooptim.backtest.data_cleaning - INFO - Raw price data shape: (104, 6)
# 2025-11-19 12:22:09,919 - allooptim.backtest.data_cleaning - WARNING - Very few symbols remain after cleaning: 6 (required: 10)
# 2025-11-19 12:22:09,921 - allooptim.backtest.data_cleaning - INFO - Clean price data shape: (104, 6) (dropped 0 symbols)
# 2025-11-19 12:22:09,923 - allooptim.backtest.data_loader - INFO - Loaded data for 6 assets over 104 days
# 2025-11-19 12:22:09,926 - allooptim.backtest.backtest_engine - INFO - Running backtest with 15 rebalancing dates
# 2025-11-19 12:22:09,919 - allooptim.backtest.data_cleaning - WARNING - Very few symbols remain after cleaning: 6 (required: 10)
# 2025-11-19 12:22:09,921 - allooptim.backtest.data_cleaning - INFO - Clean price data shape: (104, 6) (dropped 0 symbols)
# 2025-11-19 12:22:09,923 - allooptim.backtest.data_loader - INFO - Loaded data for 6 assets over 104 days
# 2025-11-19 12:22:09,926 - allooptim.backtest.backtest_engine - INFO - Running backtest with 15 rebalancing dates
# 2025-11-19 12:22:09,928 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 1/15: 2020-03-16 00:00:00
# 2025-11-19 12:22:09,934 - allooptim.optimizer.allocation_metric - WARNING - Insufficient observations (19) for reliable L-moments, minimum 20 required
# 2025-11-19 12:22:09,938 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:09,928 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 1/15: 2020-03-16 00:00:00
# 2025-11-19 12:22:09,934 - allooptim.optimizer.allocation_metric - WARNING - Insufficient observations (19) for reliable L-moments, minimum 20 required
# 2025-11-19 12:22:09,938 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:09,943 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:09,952 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:09,952 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:09,943 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:09,952 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:09,952 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:09,963 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:09,963 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:10,001 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:10,001 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,497 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 2/15: 2020-03-23 00:00:00
# 2025-11-19 12:22:13,507 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,497 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 2/15: 2020-03-23 00:00:00
# 2025-11-19 12:22:13,507 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,511 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,519 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,511 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,519 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,519 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,533 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,519 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,533 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,581 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,581 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,601 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 3/15: 2020-03-30 00:00:00
# 2025-11-19 12:22:13,609 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,601 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 3/15: 2020-03-30 00:00:00
# 2025-11-19 12:22:13,609 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,659 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,669 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,659 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,669 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,671 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,677 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,671 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,677 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,714 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,727 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 4/15: 2020-04-06 00:00:00
# 2025-11-19 12:22:13,714 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,727 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 4/15: 2020-04-06 00:00:00
# 2025-11-19 12:22:13,736 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,736 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,767 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,778 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,767 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,778 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,780 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,788 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,780 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,788 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,819 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,828 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 5/15: 2020-04-14 00:00:00
# 2025-11-19 12:22:13,819 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,828 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 5/15: 2020-04-14 00:00:00
# 2025-11-19 12:22:13,842 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,842 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,868 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,881 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,882 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,868 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,881 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,882 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,890 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,890 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:13,924 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,924 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:13,946 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 6/15: 2020-04-21 00:00:00
# 2025-11-19 12:22:13,951 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,946 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 6/15: 2020-04-21 00:00:00
# 2025-11-19 12:22:13,951 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:13,982 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,993 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,996 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:13,982 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:13,993 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:13,996 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,000 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,000 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,033 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,033 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,057 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 7/15: 2020-04-28 00:00:00
# 2025-11-19 12:22:14,065 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,057 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 7/15: 2020-04-28 00:00:00
# 2025-11-19 12:22:14,065 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,093 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,103 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,093 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,103 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,106 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,112 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,106 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,112 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,150 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,162 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 8/15: 2020-05-05 00:00:00
# 2025-11-19 12:22:14,150 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,162 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 8/15: 2020-05-05 00:00:00
# 2025-11-19 12:22:14,170 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,170 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,199 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,210 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,213 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,199 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,210 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,213 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,220 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,220 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,280 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,280 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,319 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 9/15: 2020-05-12 00:00:00
# 2025-11-19 12:22:14,319 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 9/15: 2020-05-12 00:00:00
# 2025-11-19 12:22:14,333 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,333 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,387 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,387 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,408 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,410 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,420 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,408 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,410 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,420 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,451 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,469 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 10/15: 2020-05-19 00:00:00
# 2025-11-19 12:22:14,451 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,469 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 10/15: 2020-05-19 00:00:00
# 2025-11-19 12:22:14,483 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,483 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,515 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,524 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,524 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,515 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,524 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,524 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,534 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,534 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,566 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,582 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 11/15: 2020-05-27 00:00:00
# 2025-11-19 12:22:14,566 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,582 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 11/15: 2020-05-27 00:00:00
# 2025-11-19 12:22:14,589 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,589 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,618 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,623 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,618 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,623 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,631 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,636 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,631 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,636 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,670 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,682 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 12/15: 2020-06-03 00:00:00
# 2025-11-19 12:22:14,670 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,682 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 12/15: 2020-06-03 00:00:00
# 2025-11-19 12:22:14,682 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,682 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,725 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,735 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,725 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,735 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,735 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,744 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,784 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,796 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 13/15: 2020-06-10 00:00:00
# 2025-11-19 12:22:14,735 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,744 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,784 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,796 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 13/15: 2020-06-10 00:00:00
# 2025-11-19 12:22:14,805 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,805 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,834 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,845 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,834 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,845 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:14,848 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,853 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,848 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,853 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:14,902 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,902 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:14,923 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 14/15: 2020-06-17 00:00:00
# 2025-11-19 12:22:14,936 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,923 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 14/15: 2020-06-17 00:00:00
# 2025-11-19 12:22:14,936 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:14,983 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,983 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:14,998 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:15,000 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:14,998 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:15,000 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:15,010 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:15,010 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:15,059 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:15,077 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 15/15: 2020-06-24 00:00:00
# 2025-11-19 12:22:15,059 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:15,077 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 15/15: 2020-06-24 00:00:00
# 2025-11-19 12:22:15,081 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:15,081 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-19 12:22:15,107 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:15,119 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:15,107 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-19 12:22:15,119 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-19 12:22:15,119 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:15,132 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:15,119 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-19 12:22:15,132 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-19 12:22:15,166 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:15,173 - allooptim.backtest.backtest_engine - INFO - Calculating performance for HRPOptimizer
# 2025-11-19 12:22:15,166 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-19 12:22:15,173 - allooptim.backtest.backtest_engine - INFO - Calculating performance for HRPOptimizer
# 2025-11-19 12:22:15,267 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MomentumOptimizer
# 2025-11-19 12:22:15,267 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MomentumOptimizer
# 2025-11-19 12:22:15,375 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NCOSharpeOptimizer
# 2025-11-19 12:22:15,375 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NCOSharpeOptimizer
# 2025-11-19 12:22:15,466 - allooptim.backtest.backtest_engine - INFO - Calculating performance for RiskParityOptimizer
# 2025-11-19 12:22:15,466 - allooptim.backtest.backtest_engine - INFO - Calculating performance for RiskParityOptimizer
# 2025-11-19 12:22:15,553 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MaxSharpe
# 2025-11-19 12:22:15,553 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MaxSharpe
# 2025-11-19 12:22:15,635 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NaiveOptimizer
# 2025-11-19 12:22:15,635 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NaiveOptimizer
# 2025-11-19 12:22:15,734 - allooptim.backtest.backtest_engine - INFO - Calculating performance for SPY benchmark
# 2025-11-19 12:22:15,734 - allooptim.backtest.backtest_engine - INFO - Calculating performance for SPY benchmark
# 2025-11-19 12:22:15,817 - allooptim.backtest.backtest_engine - INFO - Calculating A2A ensemble performance
# 2025-11-19 12:22:15,817 - allooptim.backtest.backtest_engine - INFO - Calculating A2A ensemble performance
# 2025-11-19 12:22:15,942 - allooptim.backtest.backtest_engine - INFO - Results directory not created, skipping A2A allocation save
# 2025-11-19 12:22:15,942 - allooptim.backtest.backtest_engine - INFO - Backtest completed
# 2025-11-19 12:22:15,942 - allooptim.backtest.backtest_engine - INFO - Results directory not created, skipping A2A allocation save
# 2025-11-19 12:22:15,942 - allooptim.backtest.backtest_engine - INFO - Backtest completed
# ✅ Backtest completed successfully!
#    Tested 8 optimizers + A2A + benchmark

# %% [markdown]
# ## 4. Analyze Results
#
# Compare the performance of individual optimizers vs A2A ensemble during the volatile COVID period.

# %%
# Extract performance data for analysis
performance_data = []

for name, data in results.items():
    if 'metrics' in data and 'sharpe_ratio' in data['metrics']:
        row = {'strategy': name}
        row.update(data['metrics'])
        performance_data.append(row)

# Create DataFrame for analysis
df_results = pd.DataFrame(performance_data)
df_results = df_results.sort_values('sharpe_ratio', ascending=False)

print("Backtest Results Summary (COVID Crash Period):")
print("=" * 60)
print(f"Test period: March-June 2020 (High volatility)")
print(f"Strategies tested: {len(df_results)}")
print(f"Available strategies: {', '.join(df_results['strategy'].tolist())}")
print()

# Show top performers
print("Performance Rankings:")
print("-" * 40)
for i, row in df_results.head().iterrows():
    print(f"{i+1:2d}. {row['strategy']}: Sharpe = {row['sharpe_ratio']:.3f}")


# Check if A2A outperformed individual optimizers
a2a_sharpe = df_results[df_results['strategy'] == 'A2AEnsemble']['sharpe_ratio'].iloc[0]
individual_avg = df_results[df_results['strategy'] != 'A2AEnsemble']['sharpe_ratio'].mean()

print("A2A Ensemble Analysis:")
print("-" * 40)
print(f"A2A Sharpe Ratio: {a2a_sharpe:.3f}")
print(f"Average Individual Sharpe: {individual_avg:.3f}")

# Check for benchmark if available
benchmark_strategies = [s for s in df_results['strategy'] if 'benchmark' in s.lower() or 'spy' in s.lower()]
if benchmark_strategies:
    spy_sharpe = df_results[df_results['strategy'] == benchmark_strategies[0]]['sharpe_ratio'].iloc[0]
    print(f"Benchmark ({benchmark_strategies[0]}) Sharpe: {spy_sharpe:.3f}")
    print(f"A2A vs Benchmark: {a2a_sharpe - spy_sharpe:.3f}")
else:
    print("No benchmark strategy found in results")

print(f"A2A vs Individual: {a2a_sharpe - individual_avg:.3f}")
# Out:
# Backtest Results Summary (COVID Crash Period):
# ============================================================
# Test period: March-June 2020 (High volatility)
# Strategies tested: 8
# Available strategies: MaxSharpe, MomentumOptimizer, HRPOptimizer, NaiveOptimizer, RiskParityOptimizer, A2AEnsemble, NCOSharpeOptimizer, SPY
#
# Performance Rankings:
# ----------------------------------------
#  5. MaxSharpe: Sharpe = 3.240
#  2. MomentumOptimizer: Sharpe = 3.101
#  1. HRPOptimizer: Sharpe = 2.101
#  6. NaiveOptimizer: Sharpe = 2.092
#  4. RiskParityOptimizer: Sharpe = 2.092
# A2A Ensemble Analysis:
# ----------------------------------------
# A2A Sharpe Ratio: 2.043
# Average Individual Sharpe: 2.187
# Benchmark (SPY) Sharpe: 0.995
# A2A vs Benchmark: 1.048
# A2A vs Individual: -0.144

# %% [markdown]
# # Simple Backtest Example
#
# This notebook demonstrates a fast backtest of portfolio optimization algorithms during a volatile period where A2A ensemble methods can shine.

# %% [markdown]
# ## 1. Import Libraries
#
# Import the necessary libraries for backtesting.

# %%
import pandas as pd
from datetime import datetime

from allooptim.config.backtest_config import BacktestConfig
from allooptim.backtest.backtest_engine import BacktestEngine

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 2. Configure Backtest
#
# Set up a fast backtest for a volatile period (COVID crash) where A2A ensemble methods excel.

# %%
# Configure a fast backtest for volatile period (COVID crash)
config_backtest = BacktestConfig(
    # Required fields
    start_date=datetime(2020, 3, 1),
    end_date=datetime(2020, 6, 30),
    # Short volatile period where A2A shines (March-June 2020)
    quick_start_date=datetime(2020, 3, 1),
    quick_end_date=datetime(2020, 6, 30),
    # Fast settings for quick execution
    rebalance_frequency=5,  # Rebalance every 5 trading days
    lookback_days=30,  # Use 30 days of historical data
    # Simple asset universe
    symbols=["AAPL", "MSFT", "AMZN", "GOOGL", "TSLA", "SPY"],
    # Use A2A with a few diverse optimizers
    optimizer_configs=[
        "MaxSharpe",
        "RiskParityOptimizer",
        "NaiveOptimizer",
        "MomentumOptimizer",
        "HRPOptimizer",
        "NCOSharpeOptimizer",
    ],
    # Quick test mode
    quick_test=True,
    # Do not store results to disk for notebook environment
    store_results=False,
)

# %% [markdown]
# ## 3. Run Backtest
#
# Execute the fast backtest to see how individual optimizers and A2A ensemble perform during market volatility.

# %%
# Initialize and run the backtest
print("Initializing backtest engine...")
backtest_engine = BacktestEngine(config_backtest)

print("Running fast backtest...")
print("This should complete in under 30 seconds...")

# Run the backtest
results = backtest_engine.run_backtest()

if results:
    print("✅ Backtest completed successfully!")
    print(f"   Tested {len([k for k in results.keys() if k != 'SPY_Benchmark'])} optimizers + A2A + benchmark")
else:
    print("❌ Backtest failed")
    raise RuntimeError("Backtest execution failed")
# Out:
# 2025-11-18 20:16:54,618 - allooptim.backtest.data_loader - INFO - Loaded universe with 6 symbols
# 2025-11-18 20:16:54,623 - allooptim.backtest.backtest_engine - INFO - Starting comprehensive backtest
# 2025-11-18 20:16:54,623 - allooptim.backtest.data_loader - INFO - Loading price data from 2020-01-31 00:00:00 to 2020-06-30 00:00:00
# 2025-11-18 20:16:54,633 - allooptim.backtest.data_loader - INFO - Loading batch 1: 6 symbols
# 2025-11-18 20:16:54,623 - allooptim.backtest.backtest_engine - INFO - Starting comprehensive backtest
# 2025-11-18 20:16:54,623 - allooptim.backtest.data_loader - INFO - Loading price data from 2020-01-31 00:00:00 to 2020-06-30 00:00:00
# 2025-11-18 20:16:54,633 - allooptim.backtest.data_loader - INFO - Loading batch 1: 6 symbols
# Initializing backtest engine...
# Running fast backtest...
# This should complete in under 30 seconds...
# 2025-11-18 20:16:54,833 - allooptim.backtest.data_cleaning - INFO - Raw price data shape: (104, 6)
# 2025-11-18 20:16:54,839 - allooptim.backtest.data_cleaning - WARNING - Very few symbols remain after cleaning: 6 (required: 10)
# 2025-11-18 20:16:54,845 - allooptim.backtest.data_cleaning - INFO - Clean price data shape: (104, 6) (dropped 0 symbols)
# 2025-11-18 20:16:54,839 - allooptim.backtest.data_cleaning - WARNING - Very few symbols remain after cleaning: 6 (required: 10)
# 2025-11-18 20:16:54,845 - allooptim.backtest.data_cleaning - INFO - Clean price data shape: (104, 6) (dropped 0 symbols)
# 2025-11-18 20:16:54,847 - allooptim.backtest.data_loader - INFO - Loaded data for 6 assets over 104 days
# 2025-11-18 20:16:54,850 - allooptim.backtest.backtest_engine - INFO - Running backtest with 15 rebalancing dates
# 2025-11-18 20:16:54,850 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 1/15: 2020-03-16 00:00:00
# 2025-11-18 20:16:54,858 - allooptim.optimizer.allocation_metric - WARNING - Insufficient observations (19) for reliable L-moments, minimum 20 required
# 2025-11-18 20:16:54,847 - allooptim.backtest.data_loader - INFO - Loaded data for 6 assets over 104 days
# 2025-11-18 20:16:54,850 - allooptim.backtest.backtest_engine - INFO - Running backtest with 15 rebalancing dates
# 2025-11-18 20:16:54,850 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 1/15: 2020-03-16 00:00:00
# 2025-11-18 20:16:54,858 - allooptim.optimizer.allocation_metric - WARNING - Insufficient observations (19) for reliable L-moments, minimum 20 required
# 2025-11-18 20:16:54,864 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:54,870 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:54,864 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:54,870 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:54,894 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:54,901 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:54,915 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:54,894 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:54,901 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:54,915 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,062 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,062 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,129 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 2/15: 2020-03-23 00:00:00
# 2025-11-18 20:16:55,129 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 2/15: 2020-03-23 00:00:00
# 2025-11-18 20:16:55,146 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,152 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,146 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,152 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,170 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,176 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,170 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,176 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,187 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,187 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,306 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,306 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,351 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 3/15: 2020-03-30 00:00:00
# 2025-11-18 20:16:55,351 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 3/15: 2020-03-30 00:00:00
# 2025-11-18 20:16:55,368 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,368 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,434 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,434 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,457 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,462 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,472 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,457 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,462 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,472 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,553 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,575 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 4/15: 2020-04-06 00:00:00
# 2025-11-18 20:16:55,553 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,575 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 4/15: 2020-04-06 00:00:00
# 2025-11-18 20:16:55,592 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,592 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,648 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,648 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,673 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,677 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,673 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,677 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,689 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,689 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,758 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,780 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 5/15: 2020-04-14 00:00:00
# 2025-11-18 20:16:55,758 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,780 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 5/15: 2020-04-14 00:00:00
# 2025-11-18 20:16:55,794 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,794 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:55,871 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,871 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:55,888 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,897 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,888 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:55,897 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:55,917 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,917 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:55,998 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:55,998 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,039 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 6/15: 2020-04-21 00:00:00
# 2025-11-18 20:16:56,039 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 6/15: 2020-04-21 00:00:00
# 2025-11-18 20:16:56,055 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,055 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,118 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,138 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,144 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,118 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,138 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,144 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,153 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:56,153 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:56,234 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,234 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,283 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 7/15: 2020-04-28 00:00:00
# 2025-11-18 20:16:56,301 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,283 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 7/15: 2020-04-28 00:00:00
# 2025-11-18 20:16:56,301 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,366 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,384 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,392 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,400 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:56,498 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,366 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,384 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,392 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,400 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:56,498 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,542 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 8/15: 2020-05-05 00:00:00
# 2025-11-18 20:16:56,567 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,542 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 8/15: 2020-05-05 00:00:00
# 2025-11-18 20:16:56,567 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,641 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,641 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,664 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,671 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,664 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,671 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,683 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:56,683 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:56,790 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,790 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:56,843 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 9/15: 2020-05-12 00:00:00
# 2025-11-18 20:16:56,843 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 9/15: 2020-05-12 00:00:00
# 2025-11-18 20:16:56,864 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,864 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:56,955 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,955 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:56,989 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,997 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:56,989 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:56,997 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,011 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,011 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,146 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,146 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,188 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 10/15: 2020-05-19 00:00:00
# 2025-11-18 20:16:57,188 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 10/15: 2020-05-19 00:00:00
# 2025-11-18 20:16:57,205 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,205 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,269 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:57,269 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:57,287 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:57,293 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,287 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:57,293 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,305 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,305 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,405 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,405 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,437 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 11/15: 2020-05-27 00:00:00
# 2025-11-18 20:16:57,454 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,437 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 11/15: 2020-05-27 00:00:00
# 2025-11-18 20:16:57,454 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,536 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:57,536 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:57,558 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:57,565 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,558 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:57,565 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,579 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,579 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,666 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,666 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,688 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 12/15: 2020-06-03 00:00:00
# 2025-11-18 20:16:57,688 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 12/15: 2020-06-03 00:00:00
# 2025-11-18 20:16:57,707 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,707 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,773 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:57,773 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:57,795 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:57,800 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,795 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:57,800 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:57,811 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,811 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:57,891 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,891 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:57,918 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 13/15: 2020-06-10 00:00:00
# 2025-11-18 20:16:57,918 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 13/15: 2020-06-10 00:00:00
# 2025-11-18 20:16:57,936 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:57,936 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:58,001 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:58,001 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:58,029 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:58,036 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:58,046 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:58,029 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:58,036 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:58,046 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:58,120 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:58,120 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:58,158 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 14/15: 2020-06-17 00:00:00
# 2025-11-18 20:16:58,158 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 14/15: 2020-06-17 00:00:00
# 2025-11-18 20:16:58,177 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:58,177 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:58,259 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:58,279 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:58,280 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:58,293 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:58,259 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:58,279 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:58,280 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:58,293 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:58,377 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:58,400 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 15/15: 2020-06-24 00:00:00
# 2025-11-18 20:16:58,377 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:58,400 - allooptim.backtest.backtest_engine - INFO - Processing rebalance 15/15: 2020-06-24 00:00:00
# 2025-11-18 20:16:58,416 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:58,416 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MaxSharpe...
# 2025-11-18 20:16:58,483 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:58,483 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for RiskParityOptimizer...
# 2025-11-18 20:16:58,504 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:58,508 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:58,504 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NaiveOptimizer...
# 2025-11-18 20:16:58,508 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for MomentumOptimizer...
# 2025-11-18 20:16:58,520 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:58,520 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for HRPOptimizer...
# 2025-11-18 20:16:58,620 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:58,620 - allooptim.allocation_to_allocators.equal_weight_orchestrator - INFO - Computing allocation for NCOSharpeOptimizer...
# 2025-11-18 20:16:58,643 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MomentumOptimizer
# 2025-11-18 20:16:58,643 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MomentumOptimizer
# 2025-11-18 20:16:58,868 - allooptim.backtest.backtest_engine - INFO - Calculating performance for RiskParityOptimizer
# 2025-11-18 20:16:58,868 - allooptim.backtest.backtest_engine - INFO - Calculating performance for RiskParityOptimizer
# 2025-11-18 20:16:59,108 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MaxSharpe
# 2025-11-18 20:16:59,308 - allooptim.backtest.backtest_engine - INFO - Calculating performance for HRPOptimizer
# 2025-11-18 20:16:59,108 - allooptim.backtest.backtest_engine - INFO - Calculating performance for MaxSharpe
# 2025-11-18 20:16:59,308 - allooptim.backtest.backtest_engine - INFO - Calculating performance for HRPOptimizer
# 2025-11-18 20:16:59,562 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NaiveOptimizer
# 2025-11-18 20:16:59,562 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NaiveOptimizer
# 2025-11-18 20:16:59,809 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NCOSharpeOptimizer
# 2025-11-18 20:16:59,809 - allooptim.backtest.backtest_engine - INFO - Calculating performance for NCOSharpeOptimizer
# 2025-11-18 20:17:00,054 - allooptim.backtest.backtest_engine - INFO - Calculating performance for SPY benchmark
# 2025-11-18 20:17:00,293 - allooptim.backtest.backtest_engine - INFO - Calculating A2A ensemble performance
# 2025-11-18 20:17:00,054 - allooptim.backtest.backtest_engine - INFO - Calculating performance for SPY benchmark
# 2025-11-18 20:17:00,293 - allooptim.backtest.backtest_engine - INFO - Calculating A2A ensemble performance
# 2025-11-18 20:17:00,548 - allooptim.backtest.backtest_engine - INFO - Results directory not created, skipping A2A allocation save
# 2025-11-18 20:17:00,550 - allooptim.backtest.backtest_engine - INFO - Backtest completed
# 2025-11-18 20:17:00,548 - allooptim.backtest.backtest_engine - INFO - Results directory not created, skipping A2A allocation save
# 2025-11-18 20:17:00,550 - allooptim.backtest.backtest_engine - INFO - Backtest completed
# ✅ Backtest completed successfully!
#    Tested 8 optimizers + A2A + benchmark

# %% [markdown]
# ## 4. Analyze Results
#
# Compare the performance of individual optimizers vs A2A ensemble during the volatile COVID period.

# %%
# Extract performance data for analysis
performance_data = []

for name, data in results.items():
    if 'metrics' in data and 'sharpe_ratio' in data['metrics']:
        row = {'strategy': name}
        row.update(data['metrics'])
        performance_data.append(row)

# Create DataFrame for analysis
df_results = pd.DataFrame(performance_data)
df_results = df_results.sort_values('sharpe_ratio', ascending=False)

print("Backtest Results Summary (COVID Crash Period):")
print("=" * 60)
print(f"Test period: March-June 2020 (High volatility)")
print(f"Strategies tested: {len(df_results)}")
print(f"Available strategies: {', '.join(df_results['strategy'].tolist())}")
print()

# Show top performers
print("Performance Rankings:")
print("-" * 40)
for i, row in df_results.head().iterrows():
    print(f"{i+1:2d}. {row['strategy']}: Sharpe = {row['sharpe_ratio']:.3f}")


# Check if A2A outperformed individual optimizers
a2a_sharpe = df_results[df_results['strategy'] == 'A2AEnsemble']['sharpe_ratio'].iloc[0]
individual_avg = df_results[df_results['strategy'] != 'A2AEnsemble']['sharpe_ratio'].mean()

print("A2A Ensemble Analysis:")
print("-" * 40)
print(f"A2A Sharpe Ratio: {a2a_sharpe:.3f}")
print(f"Average Individual Sharpe: {individual_avg:.3f}")

# Check for benchmark if available
benchmark_strategies = [s for s in df_results['strategy'] if 'benchmark' in s.lower() or 'spy' in s.lower()]
if benchmark_strategies:
    spy_sharpe = df_results[df_results['strategy'] == benchmark_strategies[0]]['sharpe_ratio'].iloc[0]
    print(f"Benchmark ({benchmark_strategies[0]}) Sharpe: {spy_sharpe:.3f}")
    print(f"A2A vs Benchmark: {a2a_sharpe - spy_sharpe:.3f}")
else:
    print("No benchmark strategy found in results")

print(f"A2A vs Individual: {a2a_sharpe - individual_avg:.3f}")
# Out:
# Backtest Results Summary (COVID Crash Period):
# ============================================================
# Test period: March-June 2020 (High volatility)
# Strategies tested: 8
# Available strategies: MaxSharpe, MomentumOptimizer, HRPOptimizer, NaiveOptimizer, RiskParityOptimizer, A2AEnsemble, NCOSharpeOptimizer, SPY
#
# Performance Rankings:
# ----------------------------------------
#  3. MaxSharpe: Sharpe = 3.240
#  1. MomentumOptimizer: Sharpe = 3.101
#  4. HRPOptimizer: Sharpe = 2.101
#  5. NaiveOptimizer: Sharpe = 2.092
#  2. RiskParityOptimizer: Sharpe = 2.092
# A2A Ensemble Analysis:
# ----------------------------------------
# A2A Sharpe Ratio: 2.043
# Average Individual Sharpe: 2.187
# Benchmark (SPY) Sharpe: 0.995
# A2A vs Benchmark: 1.048
# A2A vs Individual: -0.144
